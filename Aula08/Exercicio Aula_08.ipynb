# %% [markdown]
# Questão 1 – Leia a base de dados do seguinte endereço:
# 'https://raw.githubusercontent.com/Simone-Ingrid/datasets/main/media_disciplina.csv’
# e calcule a média das Médias Finais da turma. Usar a função
# mean() na coluna de Médias.

# %%
import pandas as pd
url = pd.read_csv('https://raw.githubusercontent.com/Simone-Ingrid/datasets/main/media_disciplina.csv' ,  encoding='unicode_escape', sep=';')
display(url.head())
# Out:
#    Núm        MATRÍCULA  AV1  AV2 MÉDIA FINAL
# 0    1  202002464716-23  NaN  1,5         0,8
# 1    2  202002464716-24    4    2           3
# 2    3  202002464716-25    6    8           7
# 3    4  202002464716-26    3    4         3,5
# 4    5  202002464716-27    1   10         5,5

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Simone-Ingrid/datasets/main/media_disciplina.csv' ,  encoding='unicode_escape', sep=';')
#url[['MÉDIA FINAL']]
df = df['MÉDIA FINAL'].str.replace(',','.').astype(float).mean()
print('Média geral: ',df)
# Out:
# Média geral:  3.2957446808510644
