# %% [markdown]
# #Desafio 4 – Seja o Dataframe de criptomoedas. Efetuar a “limpeza” e conversão dos Dados das colunas “last_price” e “%”.Após essa operação, fazer o cálculo de média, mediana e moda dessas colunas.
#
# ### usar replace ("$", "")
